# %%
import glob
import os
import pyedflib
from datetime import timedelta

# Define the folder path containing the EDF files
folder_path = '/Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard'

# Iterate through each EDF file in the folder
for file_path in glob.glob(os.path.join(folder_path, "*.edf")):
    print(f"Processing file: {file_path}")
    
    # Read each EDF file
    with pyedflib.EdfReader(file_path) as edf_reader:
        n_channels = edf_reader.signals_in_file
        signal_labels = edf_reader.getSignalLabels()
        print(f"Channels found: {signal_labels}")
        
        for types in signal_labels:
            channel_index = signal_labels.index(types)
            data = edf_reader.readSignal(channel_index)
            sfreq = edf_reader.getSampleFrequency(channel_index)
            total_duration = timedelta(seconds=len(data) / sfreq)  # Convert total duration to timedelta

            # Define interval and marker pattern
            start_time = timedelta(hours=0)  # Start from 0:00:00
            interval = timedelta(seconds=20)  # Each interval is 20 seconds
            markers = ['EMPTY']  # Example marker pattern

            # Generate rows for the required format
            output_rows = []
            current_time = start_time
            index = 1

            while current_time < total_duration:
                marker = markers[(index - 1) % len(markers)]
                row = f"{index}\t{str(current_time)}\t{marker}"
                output_rows.append(row)
                
                # Update for the next row
                current_time += interval
                index += 1

            # Join rows with newline characters
            output_txt = "\n".join(output_rows)

            # Save the output to a .txt file with the same base name
            base_name = os.path.splitext(os.path.basename(file_path))[0]
            output_path = os.path.join(folder_path, f"{base_name}.txt")
            with open(output_path, "w") as f:
                f.write(output_txt)
                
            print(f"Saved output to {output_path}")
# Out:
# Processing file: /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4y2_11m_BL_6h_edited.edf
# Channels found: ['FrL', 'FrR', 'OcR']
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4y2_11m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4y2_11m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4y2_11m_BL_6h_edited.txt
# Processing file: /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati5x1_11m_BL_6h_edited.edf
# Channels found: ['FrL', 'FrR', 'OcR']
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati5x1_11m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati5x1_11m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati5x1_11m_BL_6h_edited.txt
# Processing file: /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati5x1_10m_BL_6h_edited.edf
# Channels found: ['FrL', 'FrR', 'OcR']
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati5x1_10m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati5x1_10m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati5x1_10m_BL_6h_edited.txt
# Processing file: /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4y3_12m_BL_6h_edited.edf
# Channels found: ['FrL', 'FrR', 'OcR']
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4y3_12m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4y3_12m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4y3_12m_BL_6h_edited.txt
# Processing file: /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x1_15m_BL_6h_edited.edf
# Channels found: ['FrL', 'FrR', 'OcR']
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x1_15m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x1_15m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x1_15m_BL_6h_edited.txt
# Processing file: /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x3B_15m_H2O_6h_edited.edf
# Channels found: ['FrL', 'FrR', 'OcR']
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x3B_15m_H2O_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x3B_15m_H2O_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x3B_15m_H2O_6h_edited.txt
# Processing file: /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati5x2_12m_BL_6h_edited.edf
# Channels found: ['FrL', 'FrR', 'OcR']
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati5x2_12m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati5x2_12m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati5x2_12m_BL_6h_edited.txt
# Processing file: /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x7_14m_BL_6h_edited.edf
# Channels found: ['FrL', 'FrR', 'OcR']
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x7_14m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x7_14m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x7_14m_BL_6h_edited.txt
# Processing file: /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4y4_12m_BL_6h_edited.edf
# Channels found: ['FrL', 'FrR', 'OcR']
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4y4_12m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4y4_12m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4y4_12m_BL_6h_edited.txt
# Processing file: /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati5x3_14m_BL_6h_edited.edf
# Channels found: ['FrL', 'FrR', 'OcR']
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati5x3_14m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati5x3_14m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati5x3_14m_BL_6h_edited.txt
# Processing file: /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x3_12m_BL_6h_edited.edf
# Channels found: ['FrL', 'FrR', 'OcR']
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x3_12m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x3_12m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x3_12m_BL_6h_edited.txt
# Processing file: /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x6_14m_H2O_6h_edited.edf
# Channels found: ['FrL', 'FrR', 'OcR']
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x6_14m_H2O_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x6_14m_H2O_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x6_14m_H2O_6h_edited.txt
# Processing file: /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x1_15m_H2O_6h_edited.edf
# Channels found: ['FrL', 'FrR', 'OcR']
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x1_15m_H2O_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x1_15m_H2O_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x1_15m_H2O_6h_edited.txt
# Processing file: /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4y4_13m_BL_6h_edited.edf
# Channels found: ['FrL', 'FrR', 'OcR']
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4y4_13m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4y4_13m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4y4_13m_BL_6h_edited.txt
# Processing file: /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x6_14m_BL_6h_edited.edf
# Channels found: ['FrL', 'FrR', 'OcR']
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x6_14m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x6_14m_BL_6h_edited.txt
# Saved output to /Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard/Ati4x6_14m_BL_6h_edited.txt

# %%
folder_path = '/Users/s.vandanov/Documents/GitHub/classification-system-ekog/data/ECoG_golden_standard'  # Replace with your folder path
all_valid_intervals = process_folder(folder_path)
